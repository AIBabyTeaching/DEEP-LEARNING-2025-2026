# %% [markdown]
# # Smart Exam  Deep Learning  W01-W02
# ## Eng. Ahmed Mtwalli
#
# ---
#
# > ### IMPORTANT INSTRUCTIONS
# > 1. **Do NOT run any cells** until your instructor says **START**.
# > 2. **Run Cell 1 (UNLOCK)** first using your **9-digit registration number**
# >    and the passcode announced by your instructor.
# > 3. This exam is based only on **W01_intro_dl** and **W02_perceptron_mlp**.
# > 4. Each student receives a different seeded sample from `sklearn` datasets.
# > 5. Run each **Task cell** to reveal the question, then write your answer in the empty cell below it.
# > 6. Save regularly with `Ctrl + S`.
#
# ---
#
# ```
# This notebook is cryptographically locked.
# Its question payload and dataset sampling depend on your registration number and passcode.
# Do not modify the unlock or task cells.
# ```

# %%
from IPython.display import display, HTML
display(HTML("""
<div style='background:#0d1117;color:#c9d1d9;border-radius:14px;padding:36px;text-align:center;font-family:monospace;border:2px solid #e94560;'>
  <h2 style='color:#e94560;letter-spacing:4px;margin:8px 0'>NOTEBOOK LOCKED</h2>
  <p style='color:#8b949e;margin:6px 0'>Run the <strong style='color:#fff'>UNLOCK CELL</strong> below to begin.</p>
  <hr style='border-color:#30363d;margin:16px 0'>
  <p style='color:#484f58;font-size:11px;margin:0'>Deep Learning Smart Exam  W01-W02  Seeded sklearn data + encrypted prompts</p>
</div>
"""))
# Out:
# <div style='background:#0d1117;color:#c9d1d9;border-radius:14px;padding:36px;text-align:center;font-family:monospace;border:2px solid #e94560;'>
#   <h2 style='color:#e94560;letter-spacing:4px;margin:8px 0'>NOTEBOOK LOCKED</h2>
#   <p style='color:#8b949e;margin:6px 0'>Run the <strong style='color:#fff'>UNLOCK CELL</strong> below to begin.</p>
#   <hr style='border-color:#30363d;margin:16px 0'>
#   <p style='color:#484f58;font-size:11px;margin:0'>Deep Learning Smart Exam  W01-W02  Seeded sklearn data + encrypted prompts</p>
# </div>

# %%
#
#     UNLOCK YOUR EXAM    W01-W02    Eng. Ahmed Mtwalli
#   Enter your registration number and the exam passcode below.
#
#   Do NOT modify this cell.

import base64, hashlib, json, zlib, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, HTML
from sklearn.datasets import load_digits, make_regression

warnings.filterwarnings("ignore")

# Encrypted payloads (do not modify)
_VERIFY_TOKEN = "GciGsNR1vy0nMMFU/oa5UOZms3fxbtvVKmRZhqgO9sphL3SPZA=="
_QUESTION_PAYLOAD = "..."

def _xor(data, pwd):
    key = hashlib.sha256(pwd.encode()).digest()
    return bytes([b ^ key[i % len(key)] for i, b in enumerate(data)])

def _unlock(encoded, pwd):
    try:
        return zlib.decompress(_xor(base64.b64decode(encoded), pwd)).decode("utf-8")
    except Exception:
        return None

def _make_exam_data(seed):
    rng = np.random.default_rng(seed)

    digits = load_digits()
    all_idx = rng.permutation(len(digits.data))
    keep = all_idx[:900]

    X_images = digits.images[keep].astype("float32") / 16.0
    X_flat = digits.data[keep].astype("float32") / 16.0
    y_digits = digits.target[keep].astype("int64")

    x_reg, y_reg = make_regression(
        n_samples=140,
        n_features=1,
        noise=float(rng.integers(8, 20)),
        random_state=seed,
    )
    x_reg = x_reg.reshape(-1)
    order = np.argsort(x_reg)
    x_reg = x_reg[order]
    y_reg = y_reg[order]

    w0 = rng.normal(35.0, 8.0)
    b0 = rng.normal(5.0, 10.0)
    y_baseline = w0 * x_reg + b0

    reg_df = pd.DataFrame({
        "x": np.round(x_reg, 4),
        "y_true": np.round(y_reg, 4),
        "y_baseline": np.round(y_baseline, 4),
    })

    return X_images, X_flat, y_digits, reg_df, float(w0), float(b0)

print("=" * 60)
print("    SMART EXAM UNLOCK    W01-W02")
print("=" * 60)

_reg = input("\n  Enter your 9-digit registration number: ").strip()
if not (_reg.isdigit() and len(_reg) == 9):
    display(HTML("<div style='color:#e94560;font-weight:bold;font-size:15px'>"
                 "Invalid registration number. It must be exactly 9 digits.<br>"
                 "Re-run this cell and try again.</div>"))
    raise ValueError("Invalid registration number")

_key = input("  Enter the exam passcode: ").strip()

if _unlock(_VERIFY_TOKEN, _key) != "W01_W02_DEEP_LEARNING_EXAM_OK":
    display(HTML("<div style='color:#e94560;font-weight:bold;font-size:15px'>"
                 "Incorrect passcode. Ask your instructor and re-run this cell.</div>"))
    raise ValueError("Wrong passcode")

_QUESTIONS = json.loads(_unlock(_QUESTION_PAYLOAD, _key))

_seed = int(hashlib.sha256(f"{_key}|{_reg}".encode()).hexdigest(), 16) % (2**32)
X_images, X_flat, y_digits, reg_df, baseline_w, baseline_b = _make_exam_data(_seed)
_fp = hashlib.sha256(f"{_key}|{_reg}".encode()).hexdigest()[:12].upper()

display(HTML(f"""
<div style='background:#0d2818;color:#c9d1d9;border-radius:12px;padding:22px;font-family:monospace;border:1px solid #238636;'>
  <h3 style='color:#3fb950;margin-top:0'>Exam Unlocked Successfully</h3>
  <table style='width:100%;border-collapse:collapse'>
    <tr><td style='color:#8b949e;padding:3px 10px'>Registration</td><td style='color:#fff;padding:3px 10px'><strong>{_reg}</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>Fingerprint</td><td style='color:#fff;padding:3px 10px'><strong>{_fp}</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>Image sample</td><td style='color:#fff;padding:3px 10px'><strong>{X_images.shape[0]} images of shape {X_images.shape[1:]}</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>Regression sample</td><td style='color:#fff;padding:3px 10px'><strong>{len(reg_df)} rows</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>Scope</td><td style='color:#fff;padding:3px 10px'><strong>W01_intro_dl + W02_perceptron_mlp</strong></td></tr>
  </table>
</div>
"""))

print("\nPreview of your regression toy data:")
display(reg_df.head())

print("\nPreview image sample:")
plt.figure(figsize=(2.6, 2.6))
plt.imshow(X_images[0], cmap="gray")
plt.title(f"Label: {y_digits[0]}")
plt.axis("off")
plt.show()
# Out:
# ============================================================
#     SMART EXAM UNLOCK    W01-W02
# ============================================================
# <div style='background:#0d2818;color:#c9d1d9;border-radius:12px;padding:22px;font-family:monospace;border:1px solid #238636;'>
#   <h3 style='color:#3fb950;margin-top:0'>Exam Unlocked Successfully</h3>
#   <table style='width:100%;border-collapse:collapse'>
#     <tr><td style='color:#8b949e;padding:3px 10px'>Registration</td><td style='color:#fff;padding:3px 10px'><strong>151014361</strong></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>Fingerprint</td><td style='color:#fff;padding:3px 10px'><strong>8016486A9356</strong></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>Image sample</td><td style='color:#fff;padding:3px 10px'><strong>900 images of shape (8, 8)</strong></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>Regression sample</td><td style='color:#fff;padding:3px 10px'><strong>140 rows</strong></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>Scope</td><td style='color:#fff;padding:3px 10px'><strong>W01_intro_dl + W02_perceptron_mlp</strong></td></tr>
#   </table>
# </div>
# Preview of your regression toy data:
#         x    y_true  y_baseline
# 0 -3.0655 -109.9283    -99.2359
# 1 -2.7290  -84.1189    -86.8129
# 2 -2.3983  -76.8824    -74.6043
# 3 -1.9330  -77.1493    -57.4282
# 4 -1.8933  -48.2540    -55.9606
# Preview image sample:

# %% [markdown]
# ---
# ## Exam Tasks
# Run each **Task cell** to reveal the question, then write your solution in the empty code cell below it.
# **Do not modify the task cells.**

# %% [markdown]
# ### Task 1  `[10 pts]`

# %%
# Task 1 Question
try:
    display(Markdown(_QUESTIONS["Q1"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Use the unlocked regression toy data `reg_df` from **W01**.
#
# 1. Print the first 5 rows of `reg_df`.
# 2. Compute the Mean Squared Error between `y_true` and `y_baseline`.
# 3. Plot the points `(x, y_true)` as a scatter plot.
# 4. Plot the baseline prediction line `y_baseline` on the same figure.
# 5. In one sentence, explain what a lower MSE means.
#
# **Hints**
# - MSE is the average of squared errors.
# - You already have the predictions in the `y_baseline` column.
# - Keep the x-axis as `reg_df["x"]`.
#
# **Useful functions**
# - `reg_df.head()`
# - `np.mean(...)`
# - `plt.scatter(...)`
# - `plt.plot(...)`
# - `plt.legend()`
# - `plt.show()`

# %%
# Your solution for Task 1
# Write your code below this line.

# %% [markdown]
# ### Task 2  `[10 pts]`

# %%
# Task 2 Question
try:
    display(Markdown(_QUESTIONS["Q2"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Stay with the **W01** regression toy data.
#
# Using NumPy only:
#
# 1. Compute the gradient of MSE with respect to `w` and `b` for the current baseline line.
# 2. Perform **one** gradient-descent update step using learning rate `0.01`.
# 3. Compute the new MSE after the update.
# 4. Print the old and new values of `w`, `b`, and MSE.
# 5. State whether the update improved the fit.
#
# **Hints**
# - Use `x = reg_df["x"].values` and `y = reg_df["y_true"].values`.
# - Start from `baseline_w` and `baseline_b` from the unlock cell.
# - For predictions use `y_pred = w * x + b`.
# - For MSE gradients: `dw = (2/N) * sum((y_pred - y) * x)` and `db = (2/N) * sum(y_pred - y)`.
#
# **Useful functions**
# - `reg_df[...].values`
# - `len(x)`
# - `np.sum(...)`
# - standard Python assignment for the update step

# %%
# Your solution for Task 2
# Write your code below this line.

# %% [markdown]
# ### Task 3  `[10 pts]`

# %%
# Task 3 Question
try:
    display(Markdown(_QUESTIONS["Q3"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Work with the image dataset from **W01/W02**.
#
# The unlocked cell provides:
#
# - `X_images` with shape `(n, 8, 8)`
# - `X_flat` with shape `(n, 64)`
# - `y_digits`
#
# Tasks:
#
# 1. Print the shapes of these three objects.
# 2. Show one sample image using `plt.imshow(...)`.
# 3. Print its label.
# 4. Explain briefly what **flattening** means in this lab.
#
# **Hints**
# - Pick any sample index such as `idx = 0`.
# - `X_images[idx]` is the 2D image.
# - `X_flat[idx]` is the flattened vector for the same sample.
# - Flattening converts an image matrix into a single 1D feature vector.
#
# **Useful functions**
# - `.shape`
# - `plt.imshow(..., cmap="gray")`
# - `plt.axis("off")`
# - `print(...)`

# %%
# Your solution for Task 3
# Write your code below this line.

# %% [markdown]
# ### Task 4  `[15 pts]`

# %%
# Task 4 Question
try:
    display(Markdown(_QUESTIONS["Q4"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Build the **Week 01 baseline**: a single dense output layer on flattened pixels.
#
# 1. Split `X_flat` and `y_digits` into training and validation sets.
# 2. Build a `tf.keras.Sequential` model with:
#    - an input for 64 features
#    - one output layer for 10 classes
# 3. Train it with validation tracking.
# 4. Use early stopping.
# 5. Report final training accuracy and validation accuracy.
#
# **Hints**
# - This is the closest version to the simple Week 01 dense classifier.
# - Since labels are integers `0..9`, use `sparse_categorical_crossentropy`.
# - Your output layer should usually be `Dense(10, activation="softmax")`.
# - Early stopping should monitor validation loss.
#
# **Useful functions**
# - `train_test_split(...)`
# - `tf.keras.Sequential([...])`
# - `tf.keras.layers.Input(...)`
# - `tf.keras.layers.Dense(...)`
# - `model.compile(...)`
# - `model.fit(...)`
# - `tf.keras.callbacks.EarlyStopping(...)`

# %%
# Your solution for Task 4
# Write your code below this line.

# %% [markdown]
# ### Task 5  `[15 pts]`

# %%
# Task 5 Question
try:
    display(Markdown(_QUESTIONS["Q5"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Build an **MLP** as in **W02**.
#
# 1. Create a model with at least one hidden layer and nonlinear activation.
# 2. Train it on the same split as Task 4.
# 3. Plot training vs validation accuracy.
# 4. Plot training vs validation loss.
# 5. Compare its validation accuracy to the single-layer model from Task 4.
#
# **Hints**
# - Add at least one hidden `Dense(...)` layer before the output layer.
# - A common starting point is `relu` in the hidden layer.
# - Reuse the same train/validation split for a fair comparison.
# - The returned `history` object contains the learning curves.
#
# **Useful functions**
# - `tf.keras.Sequential([...])`
# - `tf.keras.layers.Dense(...)`
# - `history.history.keys()`
# - `plt.plot(history.history["accuracy"])`
# - `plt.plot(history.history["val_accuracy"])`
# - `plt.plot(history.history["loss"])`
# - `plt.plot(history.history["val_loss"])`

# %%
# Your solution for Task 5
# Write your code below this line.

# %% [markdown]
# ### Task 6  `[15 pts]`

# %%
# Task 6 Question
try:
    display(Markdown(_QUESTIONS["Q6"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Depth vs width was a main topic in **W02**.
#
# Train two MLPs on the same data:
#
# - Model A: a smaller network
# - Model B: a deeper or wider network
#
# Then:
#
# 1. Compare validation accuracy for both models.
# 2. Compare their learning curves.
# 3. State which model underfits or generalizes better, based on the curves.
#
# **Hints**
# - Example small model: one hidden layer such as `[32]`.
# - Example larger model: two or three hidden layers such as `[128, 64]`.
# - Keep batch size, epochs, optimizer, and split the same.
# - Compare both the final validation accuracy and the curve shapes.
#
# **Useful functions**
# - `tf.keras.Sequential([...])`
# - repeated `tf.keras.layers.Dense(...)`
# - `model.fit(...)`
# - `history.history[...]`
# - `plt.plot(...)`

# %%
# Your solution for Task 6
# Write your code below this line.

# %% [markdown]
# ### Task 7  `[10 pts]`

# %%
# Task 7 Question
try:
    display(Markdown(_QUESTIONS["Q7"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Activation experiments were also part of **W02**.
#
# 1. Keep the same architecture fixed.
# 2. Train short runs using at least **two** activations from:
#    `relu`, `tanh`, `sigmoid`, `elu`
# 3. Summarize the results in a small table or dictionary.
# 4. State which activation performed best on your sampled data.
# 5. Give one short reason for that result.
#
# **Hints**
# - Change only the activation while keeping everything else the same.
# - Store each validation accuracy in a dictionary.
# - You can loop over a list of activations.
# - Short runs are fine if the comparison is clear.
#
# **Useful functions**
# - `for act in activations:`
# - `tf.keras.layers.Dense(..., activation=act)`
# - Python dictionary updates
# - `pd.DataFrame(...)` or `print(results)`

# %%
# Your solution for Task 7
# Write your code below this line.

# %% [markdown]
# ### Task 8  `[15 pts]`

# %%
# Task 8 Question
try:
    display(Markdown(_QUESTIONS["Q8"]))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'><strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# Answer these short conceptual questions from **W01** and **W02**.
#
# 1. What is the difference between training accuracy and validation accuracy?
# 2. Why does early stopping help?
# 3. Why can a single-layer perceptron be too limited for image tasks?
# 4. What is the difference between underfitting and overfitting?
#
# Keep the answers short and precise.
#
# **Hints**
# - Focus on the core idea of each term.
# - One or two lines per answer is enough.
# - Use the wording and ideas from the labs.
#
# **Useful functions**
# - No special functions needed; short text answers are enough.

# %%
# Your solution for Task 8
# Write your code below this line.

# %% [markdown]
# ---
# ## End of Exam
# - Save your notebook with **Ctrl + S**
# - Make sure outputs are visible
# - Submit the completed `.ipynb` file
#
# > *Deep Learning Smart Exam  W01-W02  Eng. Ahmed Mtwalli*
