# %% [markdown]
# # W02 · Perceptron & Multilayer Perceptrons
#
# **Learning objectives**
#
# - Review the limitations of single-layer perceptrons and motivate deeper architectures.
# - Practice reasoning about when to add layers versus adding more neurons to existing layers.
# - Compare common activation functions and recognize how they influence optimization dynamics.
# - Build intuition for diagnosing underfitting/overfitting when designing multilayer perceptrons (MLPs).

# %% [markdown]
# ## Recap: From Perceptrons to MLPs
#
# In Week 01 we trained a single dense layer on Fashion-MNIST. The perceptron learned a linear decision boundary over flattened pixels.
#
# > **Key limitation:** Without hidden layers the model cannot express interactions between pixels. Decision boundaries remain linear, so patterns like curves, textures, or hierarchical shapes are hard to capture.
#
# To move beyond linear separability we introduce **hidden layers**. Each additional layer composes nonlinear transformations that can
# model progressively more abstract features. However, deeper networks add more parameters and optimization challenges, so we need a principled way to decide when to deepen versus widen a network.

# %% [markdown]
# ## Heuristics for Adding Layers or Neurons
#
# When designing an MLP, consider the following heuristics:
#
# - **Problem complexity**: If your features interact in hierarchical ways (e.g., strokes composing clothing items), adding layers can help. If interactions are mostly linear, widening layers might suffice.
# - **Bias vs. variance**:
#   - High bias / underfitting → add layers or neurons, or change activations to increase capacity.
#   - High variance / overfitting → reduce layers/neurons, add regularization, or collect more data.
# - **Representation bottlenecks**: Too few neurons in a critical layer can restrict information flow. Gradually increase width while monitoring validation metrics.
# - **Training dynamics**: Vanishing gradients or slow convergence could mean the architecture or activation is poorly matched; try `relu` or `elu` for deeper stacks, or add normalization.
# - **Parameter budget / inference cost**: Deeper and wider networks cost more to train/serve. Aim for the simplest model that meets your performance target.

# %% [markdown]
# ## Setup: Imports & Data Pipeline
#
# We will reuse the Fashion-MNIST dataset from Week 01. To keep experiments fast, we'll train on a 12k-image subset and hold out 2k examples for validation.

# %% [markdown]
# Q&A:
#
# - Size of an image (example 28x28 training same should apply for test)
# - Size of the training/test splits (example 80% train 20% test)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import time

print(tf.__version__)

# Load Fashion-MNIST (10 Classes)
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Normalize to [0, 1]
train_images = train_images.astype("float32") / 255.0 # floating is adopted here to keep precision of data.
test_images = test_images.astype("float32") / 255.0

# Flatten inputs for dense networks
train_images = train_images.reshape(-1, 28 * 28)
test_images = test_images.reshape(-1, 28 * 28) # the shape of test images must be same as train images

# Create train/validation split (12k train / 2k val)
val_split = 2000 # validation set.
train_subset = 12000

train_x = train_images[:train_subset] # 12k of the images are sliced
train_y = train_labels[:train_subset] # 12k of the labels are sliced
val_x = train_images[train_subset:train_subset + val_split]
val_y = train_labels[train_subset:train_subset + val_split]

class_names = [ # from the 10 classes of fashion mnist
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

print(f"Training subset: {train_x.shape}, Validation subset: {val_x.shape}")
# Out:
# 2.15.0
# Training subset: (12000, 784), Validation subset: (2000, 784)

# %% [markdown]
# ## Comparing Architectures: Depth vs. Width
#
# We'll train several `tf.keras.Sequential` models that vary in depth (number of hidden layers) and width (neurons per layer). Each model trains for a small number of epochs so we can compare validation performance quickly.

# %%
def build_mlp(hidden_layers, # Do I need to specify the number of layers? or I want to make it dynamic?
              activation="relu",
              dropout_rate=0.0, # Regularization
              learning_rate=1e-3 # Learning Rate is from 0 to 1
              ):
    # 1st step, keras.Sequential() to be used to hold the layers of the model in it.
    model = keras.Sequential(name="mlp")
    
    # 2st step, place the input layer.
    model.add(layers.Input(shape=(784,)))
    
    # 3rd step, build the hidden layers based on the number of hidden layers given and number of 128.
    for units in hidden_layers:
        model.add(layers.Dense(units, activation=activation))
        if dropout_rate > 0:
            model.add(layers.Dropout(dropout_rate))
            
    # 4th step, the output
    model.add(layers.Dense(10, activation="softmax")) # Number of classes 10.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate), # keep it aside
        loss="sparse_categorical_crossentropy", # Sparse Categorical Crossentropy Loss is used in Multi-Class Classification.
        metrics=["accuracy"]
    )
    return model

architectures = [ # we are building 3 different models.
    ("shallow_wide", [1024], "1 hidden layer, wide"), 
    ("two_layer_balanced", [256, 128], "2 hidden layers"),
    ("deep_narrow", [128, 128, 64, 64, 32], "5 hidden layers, narrower"),
]

histories = {}
training_summaries = []

for model_key, hidden_layers, description in architectures: # 3 times (for loop over the architectures)
    print(f"Training model: {model_key} ({description})")
    model = build_mlp(hidden_layers, dropout_rate=0.3)
    start_time = time.perf_counter() # start time
    history = model.fit( # for later on visualization
        train_x,
        train_y,
        validation_data=(val_x, val_y),
        epochs=25,
        batch_size=128,
        verbose=1 # to turn on the logs put verbose=1
    )
    elapsed = time.perf_counter() - start_time # end counter - timing of fitting/validation
    histories[model_key] = history.history
    val_acc = history.history["val_accuracy"][-1]
    training_summaries.append({
        "model": model_key,
        "description": description,
        "val_accuracy": val_acc,
        "train_time_sec": elapsed,
    })
    print(f"Final validation accuracy: {val_acc:.3f} (time: {elapsed:.2f}s)")

if training_summaries:
    print("Architecture comparison summary:")
    header = f"{'Model':<20}{'Description':<30}{'Val Accuracy':<15}{'Train Time (s)':<15}"
    print(header)
    print('-' * len(header))
    for summary in training_summaries:
        print(
            f"{summary['model']:<20}{summary['description']:<30}"
            f"{summary['val_accuracy']:<15.3f}{summary['train_time_sec']:<15.2f}"
        )

fig, axes = plt.subplots(1, 2, figsize=(14, 4))
for model_key, history in histories.items():
    epochs = range(1, len(history["accuracy"]) + 1)
    axes[0].plot(epochs, history["accuracy"], marker="o", label=model_key)
    axes[1].plot(epochs, history["val_accuracy"], marker="o", label=model_key)

axes[0].set_title("Training accuracy")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")

axes[1].set_title("Validation accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Training model: shallow_wide (1 hidden layer, wide)
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6669 - loss: 0.9469 - val_accuracy: 0.8220 - val_loss: 0.4987
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8245 - loss: 0.5000 - val_accuracy: 0.8415 - val_loss: 0.4395
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8393 - loss: 0.4559 - val_accuracy: 0.8375 - val_loss: 0.4499
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8572 - loss: 0.4094 - val_accuracy: 0.8535 - val_loss: 0.4006
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8700 - loss: 0.3688 - val_accuracy: 0.8505 - val_loss: 0.4038
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8695 - loss: 0.3573 - val_accuracy: 0.8555 - val_loss: 0.3997
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8719 - loss: 0.3456 - val_accuracy: 0.8615 - val_loss: 0.3764
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8877 - loss: 0.3146 - val_accuracy: 0.8645 - val_loss: 0.3789
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8969 - loss: 0.2928 - val_accuracy: 0.8595 - val_loss: 0.3683
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8841 - loss: 0.3116 - val_accuracy: 0.8495 - val_loss: 0.4020
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8935 - loss: 0.2886 - val_accuracy: 0.8655 - val_loss: 0.3661
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9006 - loss: 0.2602 - val_accuracy: 0.8625 - val_loss: 0.3753
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9011 - loss: 0.2709 - val_accuracy: 0.8540 - val_loss: 0.3911
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9054 - loss: 0.2554 - val_accuracy: 0.8640 - val_loss: 0.3784
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9109 - loss: 0.2469 - val_accuracy: 0.8615 - val_loss: 0.3669
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9165 - loss: 0.2276 - val_accuracy: 0.8635 - val_loss: 0.3807
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9144 - loss: 0.2351 - val_accuracy: 0.8725 - val_loss: 0.3681
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9158 - loss: 0.2271 - val_accuracy: 0.8830 - val_loss: 0.3640
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9136 - loss: 0.2226 - val_accuracy: 0.8700 - val_loss: 0.3829
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9167 - loss: 0.2165 - val_accuracy: 0.8785 - val_loss: 0.3737
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9193 - loss: 0.2142 - val_accuracy: 0.8725 - val_loss: 0.3729
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9259 - loss: 0.1968 - val_accuracy: 0.8770 - val_loss: 0.3727
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9193 - loss: 0.2159 - val_accuracy: 0.8690 - val_loss: 0.3891
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9278 - loss: 0.1979 - val_accuracy: 0.8505 - val_loss: 0.4340
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9302 - loss: 0.1965 - val_accuracy: 0.8710 - val_loss: 0.3955
# Final validation accuracy: 0.871 (time: 22.06s)
# Training model: two_layer_balanced (2 hidden layers)
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5456 - loss: 1.2673 - val_accuracy: 0.8070 - val_loss: 0.5419
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7780 - loss: 0.6172 - val_accuracy: 0.8280 - val_loss: 0.4788
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8122 - loss: 0.5269 - val_accuracy: 0.8385 - val_loss: 0.4307
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8338 - loss: 0.4654 - val_accuracy: 0.8475 - val_loss: 0.4013
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8460 - loss: 0.4362 - val_accuracy: 0.8470 - val_loss: 0.3925
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8538 - loss: 0.4027 - val_accuracy: 0.8565 - val_loss: 0.3861
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8546 - loss: 0.3985 - val_accuracy: 0.8610 - val_loss: 0.3822
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8620 - loss: 0.3777 - val_accuracy: 0.8525 - val_loss: 0.3819
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8670 - loss: 0.3654 - val_accuracy: 0.8600 - val_loss: 0.3742
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8668 - loss: 0.3484 - val_accuracy: 0.8615 - val_loss: 0.3730
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8716 - loss: 0.3471 - val_accuracy: 0.8650 - val_loss: 0.3586
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8766 - loss: 0.3281 - val_accuracy: 0.8690 - val_loss: 0.3627
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.3131 - val_accuracy: 0.8650 - val_loss: 0.3551
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8824 - loss: 0.3129 - val_accuracy: 0.8680 - val_loss: 0.3658
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8867 - loss: 0.3076 - val_accuracy: 0.8720 - val_loss: 0.3607
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8918 - loss: 0.2885 - val_accuracy: 0.8665 - val_loss: 0.3699
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8920 - loss: 0.2823 - val_accuracy: 0.8650 - val_loss: 0.3739
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8959 - loss: 0.2833 - val_accuracy: 0.8575 - val_loss: 0.3736
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8944 - loss: 0.2817 - val_accuracy: 0.8580 - val_loss: 0.3887
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9012 - loss: 0.2741 - val_accuracy: 0.8560 - val_loss: 0.3813
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8899 - loss: 0.2778 - val_accuracy: 0.8720 - val_loss: 0.3676
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9052 - loss: 0.2560 - val_accuracy: 0.8750 - val_loss: 0.3588
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9061 - loss: 0.2531 - val_accuracy: 0.8700 - val_loss: 0.3585
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9061 - loss: 0.2520 - val_accuracy: 0.8765 - val_loss: 0.3622
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9119 - loss: 0.2365 - val_accuracy: 0.8750 - val_loss: 0.3766
# Final validation accuracy: 0.875 (time: 13.10s)
# Training model: deep_narrow (5 hidden layers, narrower)
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2117 - loss: 2.0937 - val_accuracy: 0.6495 - val_loss: 0.9574
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5562 - loss: 1.1828 - val_accuracy: 0.6775 - val_loss: 0.7365
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6367 - loss: 0.9395 - val_accuracy: 0.7530 - val_loss: 0.6425
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7020 - loss: 0.8198 - val_accuracy: 0.7870 - val_loss: 0.5635
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7315 - loss: 0.7257 - val_accuracy: 0.7940 - val_loss: 0.5486
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7558 - loss: 0.6821 - val_accuracy: 0.8065 - val_loss: 0.5480
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7649 - loss: 0.6390 - val_accuracy: 0.8200 - val_loss: 0.4950
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7859 - loss: 0.6216 - val_accuracy: 0.8205 - val_loss: 0.5082
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7997 - loss: 0.5824 - val_accuracy: 0.8220 - val_loss: 0.4913
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8020 - loss: 0.5819 - val_accuracy: 0.8420 - val_loss: 0.4568
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8105 - loss: 0.5310 - val_accuracy: 0.8475 - val_loss: 0.4511
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8240 - loss: 0.5217 - val_accuracy: 0.8505 - val_loss: 0.4365
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8225 - loss: 0.5207 - val_accuracy: 0.8435 - val_loss: 0.4564
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8381 - loss: 0.4964 - val_accuracy: 0.8330 - val_loss: 0.4632
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8358 - loss: 0.4850 - val_accuracy: 0.8465 - val_loss: 0.4395
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8460 - loss: 0.4602 - val_accuracy: 0.8490 - val_loss: 0.4432
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8388 - loss: 0.4814 - val_accuracy: 0.8555 - val_loss: 0.4448
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8437 - loss: 0.4797 - val_accuracy: 0.8540 - val_loss: 0.4290
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8378 - loss: 0.4874 - val_accuracy: 0.8500 - val_loss: 0.4364
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8524 - loss: 0.4386 - val_accuracy: 0.8545 - val_loss: 0.4307
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8522 - loss: 0.4479 - val_accuracy: 0.8395 - val_loss: 0.4496
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8513 - loss: 0.4441 - val_accuracy: 0.8450 - val_loss: 0.4374
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8536 - loss: 0.4314 - val_accuracy: 0.8580 - val_loss: 0.4309
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8630 - loss: 0.4163 - val_accuracy: 0.8560 - val_loss: 0.4180
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8608 - loss: 0.4157 - val_accuracy: 0.8550 - val_loss: 0.4014
# Final validation accuracy: 0.855 (time: 14.25s)
# Architecture comparison summary:
# Model               Description                   Val Accuracy   Train Time (s)
# --------------------------------------------------------------------------------
# shallow_wide        1 hidden layer, wide          0.871          22.06
# two_layer_balanced  2 hidden layers               0.875          13.10
# deep_narrow         5 hidden layers, narrower     0.855          14.25

# %%
from dl_utils import visualize_model
visualize_model(model)
# Out:
# WindowsPath('model.png')

# %% [markdown]
# ### Discussion
#
# - How quickly does each architecture reach strong validation accuracy?
# - Which model shows signs of underfitting (low training + validation accuracy)?
# - Do any models hint at overfitting (training accuracy increases while validation plateaus or drops)?
#
# Use these observations to reason about when additional layers help versus when simply widening a single layer is enough.

# %% [markdown]
# ## Underfitting vs. Overfitting in Practice
#
# Architecture decisions can go wrong in both directions. We'll contrast a tiny network that lacks capacity with a very deep, wide network trained for longer without regularization to show how training and validation metrics diverge.

# %%
# Assignment
extreme_configs = [ # extreme architectures
    ("underfit_tiny", [4], "Tiny capacity (underfitting)"), # 4 neurons in 1 single hidden layer
    ("overfit_huge", [1024, 512, 512, 256, 256, 128, 128], "Deep and wide (overfitting)"),
]

extreme_histories = {}
for key, hidden_layers, description in extreme_configs:
    print(f"Training extreme model: {description}")
    model = build_mlp(hidden_layers, dropout_rate=0.0) # added dropout layer
    history = model.fit(
        train_x,
        train_y,
        validation_data=(val_x, val_y),
        epochs=25,
        batch_size=128,
        verbose=1
    )
    extreme_histories[key] = history.history
    final_train = history.history['accuracy'][-1]
    final_val = history.history['val_accuracy'][-1]
    print(f"Final train acc: {final_train:.3f}, val acc: {final_val:.3f}")
# Out:
# Training extreme model: Tiny capacity (underfitting)
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2522 - loss: 2.1173 - val_accuracy: 0.4240 - val_loss: 1.6334
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4190 - loss: 1.5955 - val_accuracy: 0.5105 - val_loss: 1.3408
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5159 - loss: 1.3101 - val_accuracy: 0.5785 - val_loss: 1.1130
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6019 - loss: 1.0693 - val_accuracy: 0.6855 - val_loss: 0.9058
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6992 - loss: 0.8823 - val_accuracy: 0.7230 - val_loss: 0.7688
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7327 - loss: 0.7708 - val_accuracy: 0.7415 - val_loss: 0.7155
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7483 - loss: 0.7263 - val_accuracy: 0.7610 - val_loss: 0.6866
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7633 - loss: 0.7087 - val_accuracy: 0.7625 - val_loss: 0.6608
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7718 - loss: 0.6720 - val_accuracy: 0.7720 - val_loss: 0.6450
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7799 - loss: 0.6414 - val_accuracy: 0.7790 - val_loss: 0.6316
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7772 - loss: 0.6432 - val_accuracy: 0.7760 - val_loss: 0.6193
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7853 - loss: 0.6238 - val_accuracy: 0.7815 - val_loss: 0.6101
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7874 - loss: 0.6206 - val_accuracy: 0.7740 - val_loss: 0.6184
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7858 - loss: 0.6161 - val_accuracy: 0.7810 - val_loss: 0.6024
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7828 - loss: 0.6156 - val_accuracy: 0.7870 - val_loss: 0.5897
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7968 - loss: 0.5814 - val_accuracy: 0.7915 - val_loss: 0.5858
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7964 - loss: 0.5779 - val_accuracy: 0.7960 - val_loss: 0.5804
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.5739 - val_accuracy: 0.7935 - val_loss: 0.5786
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7920 - loss: 0.5787 - val_accuracy: 0.7900 - val_loss: 0.5766
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7985 - loss: 0.5615 - val_accuracy: 0.7980 - val_loss: 0.5753
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8065 - loss: 0.5490 - val_accuracy: 0.7975 - val_loss: 0.5739
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8053 - loss: 0.5503 - val_accuracy: 0.8000 - val_loss: 0.5678
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8026 - loss: 0.5610 - val_accuracy: 0.7965 - val_loss: 0.5724
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8018 - loss: 0.5562 - val_accuracy: 0.8010 - val_loss: 0.5628
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8034 - loss: 0.5523 - val_accuracy: 0.7985 - val_loss: 0.5649
# Final train acc: 0.805, val acc: 0.799
# Training extreme model: Deep and wide (overfitting)
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.5473 - loss: 1.1797 - val_accuracy: 0.8015 - val_loss: 0.5152
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8107 - loss: 0.5144 - val_accuracy: 0.8345 - val_loss: 0.4426
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8408 - loss: 0.4338 - val_accuracy: 0.8460 - val_loss: 0.4408
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8476 - loss: 0.4112 - val_accuracy: 0.8345 - val_loss: 0.4551
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8663 - loss: 0.3637 - val_accuracy: 0.8660 - val_loss: 0.3745
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8751 - loss: 0.3324 - val_accuracy: 0.8415 - val_loss: 0.4250
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8860 - loss: 0.3124 - val_accuracy: 0.8565 - val_loss: 0.4052
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8757 - loss: 0.3205 - val_accuracy: 0.8595 - val_loss: 0.4031
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8955 - loss: 0.2863 - val_accuracy: 0.8530 - val_loss: 0.4144
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9030 - loss: 0.2677 - val_accuracy: 0.8710 - val_loss: 0.3951
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9059 - loss: 0.2513 - val_accuracy: 0.8645 - val_loss: 0.4195
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9075 - loss: 0.2520 - val_accuracy: 0.8635 - val_loss: 0.4296
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9042 - loss: 0.2533 - val_accuracy: 0.8555 - val_loss: 0.4406
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9110 - loss: 0.2431 - val_accuracy: 0.8670 - val_loss: 0.3967
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9188 - loss: 0.2072 - val_accuracy: 0.8650 - val_loss: 0.4748
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9272 - loss: 0.1985 - val_accuracy: 0.8635 - val_loss: 0.4750
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9218 - loss: 0.2146 - val_accuracy: 0.8675 - val_loss: 0.4155
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9226 - loss: 0.2122 - val_accuracy: 0.8720 - val_loss: 0.4141
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9233 - loss: 0.2030 - val_accuracy: 0.8560 - val_loss: 0.4727
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9212 - loss: 0.2091 - val_accuracy: 0.8630 - val_loss: 0.4452
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9247 - loss: 0.1949 - val_accuracy: 0.8725 - val_loss: 0.4356
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9353 - loss: 0.1688 - val_accuracy: 0.8765 - val_loss: 0.4142
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9347 - loss: 0.1737 - val_accuracy: 0.8735 - val_loss: 0.4538
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9345 - loss: 0.1801 - val_accuracy: 0.8765 - val_loss: 0.4900
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9401 - loss: 0.1619 - val_accuracy: 0.8715 - val_loss: 0.4707
# Final train acc: 0.943, val acc: 0.872

# %%
def plot_history_curves(histories, title_prefix=""):
    metrics = [("accuracy", "Accuracy"), ("loss", "Loss")]
    fig, axes = plt.subplots(1, len(metrics), figsize=(14, 4))
    for ax, (metric, display_name) in zip(axes, metrics):
        for key, history in histories.items():
            epochs = range(1, len(history[metric]) + 1)
            ax.plot(epochs, history[metric], label=f"{key} train")
            ax.plot(epochs, history[f'val_{metric}'], linestyle='--', label=f"{key} val")
        ax.set_title(f"{title_prefix}{display_name}")
        ax.set_xlabel("Epoch")
        ax.set_ylabel(display_name)
    handles, labels = axes[-1].get_legend_handles_labels()
    axes[-1].legend(handles, labels, loc='upper right')
    plt.tight_layout()
    plt.show()

plot_history_curves(extreme_histories, title_prefix="Extreme models: ")

# %% [markdown]
# ### What do we observe?
#
# - **Underfit tiny network**: Training and validation accuracy stay low and the losses remain high, which tells us the model doesn't have enough capacity to represent the patterns in Fashion-MNIST.
# - **Overfit huge network**: Training accuracy keeps climbing while validation accuracy plateaus and validation loss rises, showing the model memorizes the training subset but generalizes poorly.
# - **Takeaway**: Effective architectures balance depth and width with regularization. Too few layers underfit, while an overpowered network without safeguards quickly overfits.

# %% [markdown]
# ## Activation Function Experiments
#
# Activations control how information flows between layers. We'll keep a two-layer architecture fixed and vary the nonlinearities to see how they impact convergence and final accuracy.

# %%
activations = ["relu", "tanh", "sigmoid", "elu"]
activation_histories = {}
for act in activations:
    print(f"Training activation variant: {act}")
    model = build_mlp([512, 256, 256, 128], activation=act) # balanced/narrow case
    start_time = time.perf_counter()
    history = model.fit(
        train_x,
        train_y,
        validation_data=(val_x, val_y),
        epochs=25,
        batch_size=128,
        verbose=1
    )
    elapsed_time = time.perf_counter() - start_time
    activation_histories[act] = history.history
    print(f"Final validation accuracy: {history.history['val_accuracy'][-1]:.3f} - {elapsed_time:.2f}s")

plt.figure(figsize=(7, 4))
for act, history in activation_histories.items():
    epochs = range(1, len(history["val_accuracy"]) + 1)
    plt.plot(epochs, history["val_accuracy"], marker="o", label=act)
plt.title("Validation accuracy by activation")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Training activation variant: relu
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6450 - loss: 1.0220 - val_accuracy: 0.8290 - val_loss: 0.4681
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8311 - loss: 0.4715 - val_accuracy: 0.8495 - val_loss: 0.4317
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8514 - loss: 0.4099 - val_accuracy: 0.8360 - val_loss: 0.4298
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8738 - loss: 0.3594 - val_accuracy: 0.8560 - val_loss: 0.3749
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8803 - loss: 0.3292 - val_accuracy: 0.8550 - val_loss: 0.3898
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8811 - loss: 0.3092 - val_accuracy: 0.8450 - val_loss: 0.4187
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8928 - loss: 0.2923 - val_accuracy: 0.8580 - val_loss: 0.3803
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8976 - loss: 0.2718 - val_accuracy: 0.8460 - val_loss: 0.4528
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8989 - loss: 0.2702 - val_accuracy: 0.8690 - val_loss: 0.3786
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9054 - loss: 0.2420 - val_accuracy: 0.8570 - val_loss: 0.3997
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9181 - loss: 0.2233 - val_accuracy: 0.8540 - val_loss: 0.4235
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9118 - loss: 0.2317 - val_accuracy: 0.8605 - val_loss: 0.4009
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9192 - loss: 0.2080 - val_accuracy: 0.8730 - val_loss: 0.3844
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9234 - loss: 0.1959 - val_accuracy: 0.8710 - val_loss: 0.4234
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9283 - loss: 0.1953 - val_accuracy: 0.8595 - val_loss: 0.4402
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9334 - loss: 0.1810 - val_accuracy: 0.8615 - val_loss: 0.4140
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9322 - loss: 0.1757 - val_accuracy: 0.8680 - val_loss: 0.4375
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9319 - loss: 0.1759 - val_accuracy: 0.8780 - val_loss: 0.4209
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9409 - loss: 0.1567 - val_accuracy: 0.8765 - val_loss: 0.4325
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9423 - loss: 0.1498 - val_accuracy: 0.8605 - val_loss: 0.4570
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9428 - loss: 0.1423 - val_accuracy: 0.8765 - val_loss: 0.4480
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9490 - loss: 0.1330 - val_accuracy: 0.8770 - val_loss: 0.4751
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9507 - loss: 0.1339 - val_accuracy: 0.8640 - val_loss: 0.5200
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9508 - loss: 0.1268 - val_accuracy: 0.8635 - val_loss: 0.5417
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9498 - loss: 0.1413 - val_accuracy: 0.8530 - val_loss: 0.5066
# Final validation accuracy: 0.853 - 20.22s
# Training activation variant: tanh
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6589 - loss: 0.9449 - val_accuracy: 0.8145 - val_loss: 0.5044
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8317 - loss: 0.4645 - val_accuracy: 0.8400 - val_loss: 0.4241
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8442 - loss: 0.4245 - val_accuracy: 0.8525 - val_loss: 0.3968
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8682 - loss: 0.3587 - val_accuracy: 0.8395 - val_loss: 0.3942
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8733 - loss: 0.3394 - val_accuracy: 0.8515 - val_loss: 0.3886
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8841 - loss: 0.3145 - val_accuracy: 0.8555 - val_loss: 0.4029
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8879 - loss: 0.2954 - val_accuracy: 0.8540 - val_loss: 0.3960
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9029 - loss: 0.2727 - val_accuracy: 0.8560 - val_loss: 0.3886
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9031 - loss: 0.2639 - val_accuracy: 0.8325 - val_loss: 0.4452
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9024 - loss: 0.2523 - val_accuracy: 0.8650 - val_loss: 0.3733
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9092 - loss: 0.2484 - val_accuracy: 0.8540 - val_loss: 0.4004
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9161 - loss: 0.2225 - val_accuracy: 0.8670 - val_loss: 0.3832
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9250 - loss: 0.2055 - val_accuracy: 0.8720 - val_loss: 0.3703
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9194 - loss: 0.2069 - val_accuracy: 0.8650 - val_loss: 0.3893
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9273 - loss: 0.1911 - val_accuracy: 0.8620 - val_loss: 0.4101
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9349 - loss: 0.1757 - val_accuracy: 0.8715 - val_loss: 0.3986
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9419 - loss: 0.1607 - val_accuracy: 0.8665 - val_loss: 0.3891
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9426 - loss: 0.1619 - val_accuracy: 0.8585 - val_loss: 0.4250
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9327 - loss: 0.1720 - val_accuracy: 0.8625 - val_loss: 0.4276
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9442 - loss: 0.1510 - val_accuracy: 0.8545 - val_loss: 0.4445
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9461 - loss: 0.1437 - val_accuracy: 0.8650 - val_loss: 0.4393
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9551 - loss: 0.1238 - val_accuracy: 0.8515 - val_loss: 0.4959
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9547 - loss: 0.1286 - val_accuracy: 0.8575 - val_loss: 0.4522
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9554 - loss: 0.1216 - val_accuracy: 0.8610 - val_loss: 0.4812
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9592 - loss: 0.1157 - val_accuracy: 0.8570 - val_loss: 0.4741
# Final validation accuracy: 0.857 - 19.75s
# Training activation variant: sigmoid
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2069 - loss: 2.1552 - val_accuracy: 0.5650 - val_loss: 1.1576
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6191 - loss: 1.0194 - val_accuracy: 0.7160 - val_loss: 0.7063
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7281 - loss: 0.6984 - val_accuracy: 0.7410 - val_loss: 0.6263
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7620 - loss: 0.5874 - val_accuracy: 0.7795 - val_loss: 0.5450
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7910 - loss: 0.5386 - val_accuracy: 0.7995 - val_loss: 0.5196
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8242 - loss: 0.4853 - val_accuracy: 0.8345 - val_loss: 0.4701
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8417 - loss: 0.4469 - val_accuracy: 0.8440 - val_loss: 0.4477
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8548 - loss: 0.4096 - val_accuracy: 0.8500 - val_loss: 0.4294
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8649 - loss: 0.3781 - val_accuracy: 0.8455 - val_loss: 0.4076
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8715 - loss: 0.3709 - val_accuracy: 0.8430 - val_loss: 0.4236
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8750 - loss: 0.3495 - val_accuracy: 0.8570 - val_loss: 0.3962
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8930 - loss: 0.3154 - val_accuracy: 0.8635 - val_loss: 0.3859
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8913 - loss: 0.3087 - val_accuracy: 0.8615 - val_loss: 0.3828
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8903 - loss: 0.3085 - val_accuracy: 0.8540 - val_loss: 0.3960
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8939 - loss: 0.2954 - val_accuracy: 0.8350 - val_loss: 0.4678
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8920 - loss: 0.3055 - val_accuracy: 0.8440 - val_loss: 0.4289
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8982 - loss: 0.2832 - val_accuracy: 0.8655 - val_loss: 0.3740
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9084 - loss: 0.2549 - val_accuracy: 0.8705 - val_loss: 0.3741
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9189 - loss: 0.2437 - val_accuracy: 0.8495 - val_loss: 0.4405
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9113 - loss: 0.2543 - val_accuracy: 0.8685 - val_loss: 0.3795
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9198 - loss: 0.2304 - val_accuracy: 0.8705 - val_loss: 0.3819
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9119 - loss: 0.2551 - val_accuracy: 0.8625 - val_loss: 0.3985
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9250 - loss: 0.2124 - val_accuracy: 0.8705 - val_loss: 0.3833
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9168 - loss: 0.2288 - val_accuracy: 0.8720 - val_loss: 0.3825
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9329 - loss: 0.1990 - val_accuracy: 0.8655 - val_loss: 0.3920
# Final validation accuracy: 0.865 - 20.82s
# Training activation variant: elu
# Epoch 1/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6788 - loss: 0.9043 - val_accuracy: 0.8155 - val_loss: 0.5026
# Epoch 2/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8298 - loss: 0.4685 - val_accuracy: 0.8470 - val_loss: 0.4311
# Epoch 3/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8426 - loss: 0.4229 - val_accuracy: 0.8320 - val_loss: 0.4471
# Epoch 4/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8637 - loss: 0.3638 - val_accuracy: 0.8500 - val_loss: 0.4103
# Epoch 5/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8630 - loss: 0.3581 - val_accuracy: 0.8425 - val_loss: 0.4220
# Epoch 6/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8768 - loss: 0.3301 - val_accuracy: 0.8510 - val_loss: 0.4192
# Epoch 7/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8921 - loss: 0.2868 - val_accuracy: 0.8550 - val_loss: 0.4151
# Epoch 8/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8920 - loss: 0.2924 - val_accuracy: 0.8610 - val_loss: 0.3967
# Epoch 9/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8986 - loss: 0.2674 - val_accuracy: 0.8590 - val_loss: 0.4054
# Epoch 10/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9037 - loss: 0.2522 - val_accuracy: 0.8555 - val_loss: 0.4066
# Epoch 11/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9055 - loss: 0.2490 - val_accuracy: 0.8660 - val_loss: 0.4007
# Epoch 12/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9098 - loss: 0.2344 - val_accuracy: 0.8745 - val_loss: 0.3952
# Epoch 13/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9156 - loss: 0.2186 - val_accuracy: 0.8475 - val_loss: 0.4735
# Epoch 14/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9082 - loss: 0.2337 - val_accuracy: 0.8615 - val_loss: 0.4344
# Epoch 15/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9230 - loss: 0.1990 - val_accuracy: 0.8515 - val_loss: 0.4935
# Epoch 16/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9259 - loss: 0.1945 - val_accuracy: 0.8605 - val_loss: 0.4800
# Epoch 17/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9240 - loss: 0.1937 - val_accuracy: 0.8650 - val_loss: 0.4585
# Epoch 18/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9349 - loss: 0.1714 - val_accuracy: 0.8660 - val_loss: 0.4988
# Epoch 19/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9363 - loss: 0.1683 - val_accuracy: 0.8655 - val_loss: 0.4767
# Epoch 20/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9321 - loss: 0.1778 - val_accuracy: 0.8475 - val_loss: 0.5052
# Epoch 21/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9386 - loss: 0.1517 - val_accuracy: 0.8445 - val_loss: 0.5275
# Epoch 22/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9314 - loss: 0.1732 - val_accuracy: 0.8640 - val_loss: 0.4849
# Epoch 23/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9449 - loss: 0.1435 - val_accuracy: 0.8535 - val_loss: 0.5041
# Epoch 24/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9494 - loss: 0.1279 - val_accuracy: 0.8695 - val_loss: 0.4890
# Epoch 25/25
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9500 - loss: 0.1262 - val_accuracy: 0.8665 - val_loss: 0.5280
# Final validation accuracy: 0.867 - 19.43s

# %% [markdown]
# ### Activation Takeaways & Assignments
#
# - `relu` (and variants like `elu`) often accelerate training in deeper networks because they mitigate vanishing gradients.
# - Saturating activations (`sigmoid`, `tanh`) can struggle without careful initialization or normalization but may still perform competitively with fewer layers.
# - Observe whether activations converge to similar validation accuracy despite different training trajectories.
#
# > **Try it:** Mix activations across layers (e.g., first layer `relu`, second `tanh`) and see how the dynamics change.

# %% [markdown]
# ## Guided Exercises
#
# 1. **Architecture tuning**: Modify `architectures` to include a very small network (e.g., `[64]`) and a very deep one (e.g., six layers). Compare validation accuracy and discuss bias/variance trade-offs.
# 2. **Regularization challenge**: Extend the new underfitting/overfitting section by adding dropout, `layers.BatchNormalization()`, or early stopping to the overfitting model. How much can you shrink the validation gap?
# 3. **Activation sweep**: Experiment with `swish` (`tf.nn.swish`) or `gelu`. You can pass a callable to the `activation` argument.
# 4. **TensorBoard logging (optional)**: Wrap training with `keras.callbacks.TensorBoard(log_dir="runs/week02")` to visualize losses and gradients. Record at least one screenshot of your TensorBoard scalars.
# 5. **Reflection**: For each experiment, note (a) the architecture, (b) activation(s), and (c) final training/validation accuracy. Summarize which design choices worked best and why.

# %% [markdown]
# ## Week 02 Summary Table
#
# | Section | Focus | Key Takeaways |
# | --- | --- | --- |
# | Learning Objectives | Goals for the lab | Understand perceptron limitations, experiment with MLP depth/width, and practice diagnosing model capacity issues. |
# | Data Preparation | Fashion-MNIST setup | Normalize, flatten, and create train/validation splits to enable rapid architecture experiments. |
# | Architecture Comparison | Narrow vs. balanced vs. wide MLPs | Observe how layer depth and width influence convergence speed, accuracy, and runtime. |
# | Underfitting vs. Overfitting | Extreme architectures | Contrast tiny and deep-unregularized networks to see bias/variance trade-offs in metrics. |
# | Activation Function Experiments | Nonlinearity sweep | Evaluate ReLU, tanh, sigmoid, and ELU to highlight their impact on training dynamics. |
# | Guided Exercises | Practice extensions | Encourage further tuning, regularization, and logging to consolidate Week 02 concepts. |

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

z = np.linspace(-5, 5, 400)
activations = {
    "ReLU": tf.nn.relu(z),
    "ELU": tf.nn.elu(z),
    "Tanh": tf.nn.tanh(z),
    "Sigmoid": tf.nn.sigmoid(z),
}

plt.figure(figsize=(8, 5))
for name, values in activations.items():
    plt.plot(z, values, label=name)
plt.title("Activation Functions Covered So Far")
plt.xlabel("Input (z)")
plt.ylabel("Activation(z)")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Activation Function Reference
#
# | Activation | Equation | When to reach for it |
# | --- | --- | --- |
# | **ReLU** | $f(z) = \max(0, z)$ | Baseline choice in `build_mlp`; keeps gradients alive in deeper MLP stacks so they train quickly. |
# | **ELU** | $f(z) = \begin{cases} z, & z > 0 \\ \alpha(e^{z}-1), & z \le 0 \end{cases}$ | Smooth extension of ReLU that also alleviates vanishing gradients while allowing negative outputs. |
# | **tanh** | $f(z) = \tanh(z) = \dfrac{e^{z}-e^{-z}}{e^{z}+e^{-z}}$ | Saturating activation; works best in the shallower, variants when initialization and normalization are tuned. |
# | **Sigmoid** | $f(z) = \sigma(z) = \dfrac{1}{1+e^{-z}}$ | Another saturating option; expect slower convergence unless you pair it with supportive initialization/normalization. |
